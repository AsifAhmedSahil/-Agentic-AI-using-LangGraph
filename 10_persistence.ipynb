# %% [markdown]
# persistence holo langgraph er akta feature jeta kina fault tolerance , mane amr workflow kothao crash krle next time oikhan theke start krbe. messages er belai chat bot er messages save na krle oita next time r back asbe na. so ei concept ta important for resume chat.
# # checkpointer in persistance
# per check point e state er value save krbe,
# checkpointer sob super step e thake , all super step e ki data state e ache seta database e save kore
#
# # threads in persistence
# persistence apply korar somoi akta thread id assign krte hbe workflow k , mane ami data store korar somoi kon thread er data oi id dia store krbo, bcoz jokon lagbe tokon thread id dia db theke nibo. j conversation resume korte hbe oi thread id dia db theke ber krbo.

# %% [markdown]
# ## benefits of persistence
# 1/ short time memory - last 9_chatbot file e ache explaination with code - inmemorysaver
# 2/ faulte tolerance - workflow choltese resume krle jekhan theke resume krlam oikhan theke abr start hbe
# 3/ humman in the loop - kichu kaj kortese llm human theke permission kujtese jotokkon dibe na permission totokkon execute krbe na,
# 4/ time travel - cyle configurable id dia oi state theke abr generate korte parbo sob again
